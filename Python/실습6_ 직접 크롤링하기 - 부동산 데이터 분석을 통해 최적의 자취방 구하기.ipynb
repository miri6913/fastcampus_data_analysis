# %% [markdown]
# # **부동산 데이터: 최적의 자취방 구하기**

# %% [markdown]
# ## **크롤링**

# %%
# !pip install user-agent
# Out:
# Requirement already satisfied: user-agent in /usr/local/lib/python3.10/dist-packages (0.1.10)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from user-agent) (1.16.0)

# %%
from user_agent import generate_user_agent, generate_navigator
user_agent = generate_user_agent()
user_agent
# Out:
# 'Mozilla/5.0 (X11; Ubuntu; Linux i686 on x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.120 Safari/537.36'

# %%
import requests
import numpy as np
import pandas as pd

# %%
from tqdm.notebook import tqdm
import time

# %%
article_list = []
for i in tqdm(range(1, 101)):
    try:
        url = f'https://m.land.naver.com/cluster/ajax/articleList?itemId=&mapKey=&lgeo=&showR0=&rletTpCd=OPST%3AVL%3AOR&tradTpCd=B2&z=12&lat=37.481021&lon=126.951601&btm=37.3398975&lft=126.6762562&top=37.6218785&rgt=127.2269458&totCnt=8360&cortarNo=1162000000&sort=rank&page={i}'

        user_agent = generate_user_agent()
        headers = {'User-Agent':user_agent}

        res = requests.get(url, headers=headers)
        time.sleep(1)

        article_json = res.json()
        article_body = article_json['body']
        article_list.append(article_body)
    except:
        break
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
article_list1 = [j for i in article_list for j in i]

# %%
data = pd.DataFrame(article_list1)

# %%
data = data[['atclNo','rletTpNm','flrInfo','rentPrc','hanPrc','spc1','spc2','direction','atclCfmYmd','repImgUrl','lat','lng','atclFetrDesc','tagList']]
data.columns = ['물건번호','구분','층수(물건층/전체층)','월세','보증금','계약면적(m2)','전용면적(m2)','방향','확인일자','이미지','위도','경도','설명','태그']
data
# Out:
#             물건번호  구분 층수(물건층/전체층)  월세       보증금 계약면적(m2) 전용면적(m2)   방향  \
# 0     2339667467  원룸         2/4  55     1,000       26     19.8  남서향
# 1     2339651668  원룸         중/7  40     1,000       19     16.5  북동향
# 2     2339487647  원룸         4/8  43       100       19     19.9   북향
# 3     2339568890  원룸         2/5  40     1,000       20       16   서향
# 4     2339676856  원룸         7/9  33       200       19    16.52   남향
# ...          ...  ..         ...  ..       ...      ...      ...  ...
# 1995  2339187707  원룸         3/4  35       300       23    19.84  남동향
# 1996  2339171817  원룸         3/6  10  1억 5,000       29    26.44   남향
# 1997  2339196833  원룸         1/3  60     1,000        -       29  북동향
# 1998  2339193479  원룸         1/5  65     5,000        -       24  남동향
# 1999  2339173014  원룸         1/5  30     1,000        -    16.52  남동향
#
#            확인일자                                                이미지         위도  \
# 0     23.09.15.  /20230915_104/land_naver_1694770741540Yco5Q_JP...  37.479689
# 1     23.09.15.  /20230915_166/land_naver_16947709207628XSkm_JP...  37.479887
# 2     23.09.15.  /20230915_251/land_naver_1694787000581r4F16_JP...  37.485412
# 3     23.09.15.  /20230915_271/land_naver_1694770562663jy052_JP...  37.478551
# 4     23.09.15.  /20230915_180/land_naver_1694787002217YGslS_JP...  37.485598
# ...         ...                                                ...        ...
# 1995  23.09.12.  /20230912_116/land_naver_1694487156013f9nE6_JP...  37.478363
# 1996  23.09.12.  /20230912_90/land_naver_1694485518591OfHlz_JPE...  37.484940
# 1997  23.09.12.  /20230912_88/land_naver_1694488675773UOkqf_JPE...  37.476486
# 1998  23.09.12.  /20230912_295/land_naver_1694488276372z8vWM_JP...  37.482470
# 1999  23.09.12.  /20230912_230/land_naver_1694484914347J0J85_JP...  37.479498
#
#               경도                                 설명                    태그
# 0     126.939191  봉천역도보권 신축급 채광좋고 방사이즈 좋은 깔끔한 분리형원룸   [10년이내, 융자금적은, 역세권]
# 1     126.946841      SUV 무료주차 좋음 , 보안 CCTV 좋음  정남향  [25년이내, 융자금없는, 소형평수]
# 2     126.932721       애완동물가능 신림역원룸 저렴하기로 최고 가성비갑원룸   [25년이내, 융자금적은, 역세권]
# 3     126.964993                 낙성대역세권 수리되어 깔끔한 원룸   [25년이내, 융자금적은, 역세권]
# 4     126.928802           신림역 도보 2분  가성비 좋은 지상층 원룸   [15년이내, 융자금없는, 역세권]
# ...          ...                                ...                   ...
# 1995  126.962085          고시원보다 싼 주차가능한 풀옵션 꿀매물 미쳤다   [25년이상, 융자금적은, 역세권]
# 1996  126.947014       봉천역서울대입구역 1.5룸 신축급 전세 놓치지마세요  [10년이내, 융자금적은, 소형평수]
# 1997  126.932206                        가성비넘나 좋은 그방   [10년이내, 융자금적은, 역세권]
# 1998  126.924457                     신축급, 위치좋은 깔끔한집     [2년이내, 융자금적은, 1층]
# 1999  126.932206   2호선 역세권 지상층 가성비 깔끔한 원룸 보증금 조정 가능   [25년이내, 융자금적은, 역세권]
#
# [2000 rows x 14 columns]

# %%
data.to_excel('/content/drive/MyDrive/강의자료_황수현_Python/Part3) 파이썬 데이터 분석 프로젝트/data/실습6: 직접 크롤링하기 - 부동산 데이터 분석을 통해 최적의 자취방 구하기/data.xlsx')

# %% [markdown]
# ## **질문 만들기**

# %% [markdown]
# - 최적의 자취방 구하기
#     - 내가 원하는 조건은?
#         1. 보증금 3000만원 이하
#         2. 월세는 저렴할수록 좋음
#         3. 지하, 반지하, 꼭대기층은 선호하지 않음
#         4. 전용면적이 클수록 좋음
#         5. 북향은 선호하지 않음
#         6. 연식이 오래되지 않을수록 좋음
#         7. 지하철 역에서 가까울수록 좋음

# %% [markdown]
# ## **데이터 전처리**

# %%
import plotly.express as px
import folium

import warnings
warnings.filterwarnings(action='ignore')

# %%
data = pd.read_excel('/content/drive/MyDrive/강의자료_황수현_Python/Part3) 파이썬 데이터 분석 프로젝트/data/실습6: 직접 크롤링하기 - 부동산 데이터 분석을 통해 최적의 자취방 구하기/data.xlsx')

# %%
data.head()
# Out:
#    Unnamed: 0        물건번호  구분 층수(물건층/전체층)  월세    보증금 계약면적(m2)  전용면적(m2)   방향  \
# 0           0  2339667467  원룸         2/4  55  1,000       26     19.80  남서향
# 1           1  2339651668  원룸         중/7  40  1,000       19     16.50  북동향
# 2           2  2339487647  원룸         4/8  43    100       19     19.90   북향
# 3           3  2339568890  원룸         2/5  40  1,000       20     16.00   서향
# 4           4  2339676856  원룸         7/9  33    200       19     16.52   남향
#
#         확인일자                                                이미지         위도  \
# 0  23.09.15.  /20230915_104/land_naver_1694770741540Yco5Q_JP...  37.479689
# 1  23.09.15.  /20230915_166/land_naver_16947709207628XSkm_JP...  37.479887
# 2  23.09.15.  /20230915_251/land_naver_1694787000581r4F16_JP...  37.485412
# 3  23.09.15.  /20230915_271/land_naver_1694770562663jy052_JP...  37.478551
# 4  23.09.15.  /20230915_180/land_naver_1694787002217YGslS_JP...  37.485598
#
#            경도                                 설명                          태그
# 0  126.939191  봉천역도보권 신축급 채광좋고 방사이즈 좋은 깔끔한 분리형원룸   ['10년이내', '융자금적은', '역세권']
# 1  126.946841      SUV 무료주차 좋음 , 보안 CCTV 좋음  정남향  ['25년이내', '융자금없는', '소형평수']
# 2  126.932721       애완동물가능 신림역원룸 저렴하기로 최고 가성비갑원룸   ['25년이내', '융자금적은', '역세권']
# 3  126.964993                 낙성대역세권 수리되어 깔끔한 원룸   ['25년이내', '융자금적은', '역세권']
# 4  126.928802           신림역 도보 2분  가성비 좋은 지상층 원룸   ['15년이내', '융자금없는', '역세권']

# %%
data = data.iloc[:,1:]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   물건번호         2000 non-null   int64
#  1   구분           2000 non-null   object
#  2   층수(물건층/전체층)  2000 non-null   object
#  3   월세           2000 non-null   int64
#  4   보증금          2000 non-null   object
#  5   계약면적(m2)     2000 non-null   object
#  6   전용면적(m2)     2000 non-null   float64
#  7   방향           2000 non-null   object
#  8   확인일자         2000 non-null   object
#  9   이미지          1912 non-null   object
#  10  위도           2000 non-null   float64
#  11  경도           2000 non-null   float64
#  12  설명           1841 non-null   object
#  13  태그           2000 non-null   object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 218.9+ KB

# %% [markdown]
# - 월세 0원인 경우 제외

# %%
data = data.query('월세 > 0')

# %% [markdown]
# - 보증금 숫자로 변환

# %%
data['보증금'].unique()
# Out:
# array(['1,000', '100', '200', '1억', '300', '500', '4,000', '3,000',
#        '5,000', '2,000', '3,700', '6,000', '3억', '1억 3,500', '2,500',
#        '150', '50', '9,000', '8,500', '2억 2,000', '1억 2,000', '2억', '70',
#        '7,000', '1억 1,000', '8,000', '6,500', '1억 6,000', '1억 4,000',
#        '1억 5,000', '700', '5,500', '7,600', '60', '3억 2,000', '600',
#        '1억 9,000', '2억 7,650', '1억 8,000', '8,900', '7,500', '2억 4,000',
#        '2억 9,800', '2억 7,300', '1억 3,000', '1억 2,500', '2억 5,000',
#        '2억 3,000', '2억 6,000', '2억 8,900', '3,500', '8,700', '2억 9,000',
#        '2억 4,600', '2억 8,500', '1억 7,000', '400', '2억 3,560', '1,500',
#        '6,450', '1,100', '1억 7,500', '1억 9,800', '3,400'], dtype=object)

# %%
data = data.query('~보증금.str.contains("억")')

# %%
data['보증금'].unique()
# Out:
# array(['1,000', '100', '200', '300', '500', '4,000', '3,000', '5,000',
#        '2,000', '3,700', '6,000', '2,500', '150', '50', '9,000', '8,500',
#        '70', '7,000', '8,000', '6,500', '700', '5,500', '7,600', '60',
#        '600', '8,900', '7,500', '3,500', '8,700', '400', '1,500', '6,450',
#        '1,100', '3,400'], dtype=object)

# %%
data['보증금'] = data['보증금'].str.replace(',','').astype(int)
data['보증금'].unique()
# Out:
# array([1000,  100,  200,  300,  500, 4000, 3000, 5000, 2000, 3700, 6000,
#        2500,  150,   50, 9000, 8500,   70, 7000, 8000, 6500,  700, 5500,
#        7600,   60,  600, 8900, 7500, 3500, 8700,  400, 1500, 6450, 1100,
#        3400])

# %% [markdown]
# - 물건층과 전체층 분리 후 1층과 꼭대기층 유무 컬럼 만들기
#     - 지하의 경우 마이너스로 표시

# %%
data[['물건층','전체층']] = data['층수(물건층/전체층)'].str.split('/', expand=True)

# %%
data.head()
# Out:
#          물건번호  구분 층수(물건층/전체층)  월세   보증금 계약면적(m2)  전용면적(m2)   방향       확인일자  \
# 0  2339667467  원룸         2/4  55  1000       26     19.80  남서향  23.09.15.
# 1  2339651668  원룸         중/7  40  1000       19     16.50  북동향  23.09.15.
# 2  2339487647  원룸         4/8  43   100       19     19.90   북향  23.09.15.
# 3  2339568890  원룸         2/5  40  1000       20     16.00   서향  23.09.15.
# 4  2339676856  원룸         7/9  33   200       19     16.52   남향  23.09.15.
#
#                                                  이미지         위도          경도  \
# 0  /20230915_104/land_naver_1694770741540Yco5Q_JP...  37.479689  126.939191
# 1  /20230915_166/land_naver_16947709207628XSkm_JP...  37.479887  126.946841
# 2  /20230915_251/land_naver_1694787000581r4F16_JP...  37.485412  126.932721
# 3  /20230915_271/land_naver_1694770562663jy052_JP...  37.478551  126.964993
# 4  /20230915_180/land_naver_1694787002217YGslS_JP...  37.485598  126.928802
#
#                                   설명                          태그 물건층 전체층
# 0  봉천역도보권 신축급 채광좋고 방사이즈 좋은 깔끔한 분리형원룸   ['10년이내', '융자금적은', '역세권']   2   4
# 1      SUV 무료주차 좋음 , 보안 CCTV 좋음  정남향  ['25년이내', '융자금없는', '소형평수']   중   7
# 2       애완동물가능 신림역원룸 저렴하기로 최고 가성비갑원룸   ['25년이내', '융자금적은', '역세권']   4   8
# 3                 낙성대역세권 수리되어 깔끔한 원룸   ['25년이내', '융자금적은', '역세권']   2   5
# 4           신림역 도보 2분  가성비 좋은 지상층 원룸   ['15년이내', '융자금없는', '역세권']   7   9

# %%
data['물건층'].unique()
# Out:
# array(['2', '중', '4', '7', '저', '3', '1', '5', 'B1', '13', '8', '6', '고',
#        '11', '9', '10', '17', '12', '22', 'B2'], dtype=object)

# %%
def floor_info(target, total):
    try:
        if target in ['B1','B2']: #지하이면
            return 'y'
        elif int(target) == 1 or int(target)/int(total) == 1: #1층이거나 꼭대기층이면
            return 'y'
        else:
            return 'n'
    except ValueError:
        return 'n'

# %%
data['비선호층여부'] = data.apply(lambda x: floor_info(x['물건층'], x['전체층']), axis=1)

# %%
data.head()
# Out:
#          물건번호  구분 층수(물건층/전체층)  월세   보증금 계약면적(m2)  전용면적(m2)   방향       확인일자  \
# 0  2339667467  원룸         2/4  55  1000       26     19.80  남서향  23.09.15.
# 1  2339651668  원룸         중/7  40  1000       19     16.50  북동향  23.09.15.
# 2  2339487647  원룸         4/8  43   100       19     19.90   북향  23.09.15.
# 3  2339568890  원룸         2/5  40  1000       20     16.00   서향  23.09.15.
# 4  2339676856  원룸         7/9  33   200       19     16.52   남향  23.09.15.
#
#                                                  이미지         위도          경도  \
# 0  /20230915_104/land_naver_1694770741540Yco5Q_JP...  37.479689  126.939191
# 1  /20230915_166/land_naver_16947709207628XSkm_JP...  37.479887  126.946841
# 2  /20230915_251/land_naver_1694787000581r4F16_JP...  37.485412  126.932721
# 3  /20230915_271/land_naver_1694770562663jy052_JP...  37.478551  126.964993
# 4  /20230915_180/land_naver_1694787002217YGslS_JP...  37.485598  126.928802
#
#                                   설명                          태그 물건층 전체층  \
# 0  봉천역도보권 신축급 채광좋고 방사이즈 좋은 깔끔한 분리형원룸   ['10년이내', '융자금적은', '역세권']   2   4
# 1      SUV 무료주차 좋음 , 보안 CCTV 좋음  정남향  ['25년이내', '융자금없는', '소형평수']   중   7
# 2       애완동물가능 신림역원룸 저렴하기로 최고 가성비갑원룸   ['25년이내', '융자금적은', '역세권']   4   8
# 3                 낙성대역세권 수리되어 깔끔한 원룸   ['25년이내', '융자금적은', '역세권']   2   5
# 4           신림역 도보 2분  가성비 좋은 지상층 원룸   ['15년이내', '융자금없는', '역세권']   7   9
#
#   비선호층여부
# 0      n
# 1      n
# 2      n
# 3      n
# 4      n

# %% [markdown]
# - 제외 조건에 해당하는 매물 제외
#     - 내가 원하는 조건은?
#         1. 보증금 3000만원 이하
#         2. 월세는 저렴할수록 좋음
#         3. 지하, 반지하, 꼭대기층은 선호하지 않음
#         4. 전용면적이 클수록 좋음
#         5. 북향은 선호하지 않음
#         6. 연식이 오래되지 않을수록 좋음
#         7. 지하철 역에서 가까울수록 좋음

# %%
#보증금 3000만원 이하
#지하, 반지하, 꼭대기층은 선호하지 않음
#북향은 선호하지 않음
data_filtered = data.query('300 <= 보증금 <= 3000 and 비선호층여부 == "n" and 전체층 != "1" and ~방향.str.contains("북")')

# %%
data_filtered
# Out:
#             물건번호  구분 층수(물건층/전체층)   월세   보증금 계약면적(m2)  전용면적(m2)   방향  \
# 0     2339667467  원룸         2/4   55  1000       26     19.80  남서향
# 3     2339568890  원룸         2/5   40  1000       20     16.00   서향
# 8     2339681933  원룸         3/6   45   300       19     16.52   서향
# 10    2339663561  원룸         저/4   35   500       26     19.80   서향
# 14    2339661926  원룸         저/4   50  1000       26     19.80   동향
# ...          ...  ..         ...  ...   ...      ...       ...  ...
# 1985  2339185628  빌라         중/4  100  2000       42     39.67  남동향
# 1986  2339175088  원룸         저/3   40   500       23     21.00  남동향
# 1988  2339199717  원룸         고/4   45   500       26     21.49  남동향
# 1989  2339203612  빌라         3/5   90  2000       52     45.60   서향
# 1995  2339187707  원룸         3/4   35   300       23     19.84  남동향
#
#            확인일자                                                이미지         위도  \
# 0     23.09.15.  /20230915_104/land_naver_1694770741540Yco5Q_JP...  37.479689
# 3     23.09.15.  /20230915_271/land_naver_1694770562663jy052_JP...  37.478551
# 8     23.09.15.  /20230915_295/land_naver_1694786940564F4hWf_JP...  37.486020
# 10    23.09.15.  /20230915_24/land_naver_1694770860861HB3gt_JPE...  37.484998
# 14    23.09.15.  /20230915_72/land_naver_1694770860633nCaXR_JPE...  37.484270
# ...         ...                                                ...        ...
# 1985  23.09.12.  /20230912_39/land_naver_1694487076985hxWAX_JPE...  37.473537
# 1986  23.09.12.  /20230912_15/land_naver_1694486124687snJyq_JPE...  37.474253
# 1988  23.09.12.  /20230914_12/land_naver_1694688064189IVgCU_JPE...  37.475558
# 1989  23.09.12.                                                NaN  37.472359
# 1995  23.09.12.  /20230912_116/land_naver_1694487156013f9nE6_JP...  37.478363
#
#               경도                                 설명  \
# 0     126.939191  봉천역도보권 신축급 채광좋고 방사이즈 좋은 깔끔한 분리형원룸
# 3     126.964993                 낙성대역세권 수리되어 깔끔한 원룸
# 8     126.927202      신림역  가성비 짱 분리형 원룸  위치도 너무 좋아요
# 10    126.952802      서울대입구역도보권 신축급 가성비좋은 깨끗한 풀옵션원룸
# 14    126.949405         서울대입구역도보권 방크기 좋은 깔끔한 분리형원룸
# ...          ...                                ...
# 1985  126.963900                                NaN
# 1986  126.977329                역세권 깔끔하고 좋은 집 나왔습니다
# 1988  126.936207             도림천뷰 인스타감성 초역세권 원룸꾸미기
# 1989  126.919879      대로변 버스정류장바로 뒤.올수리.거실있는 방3개 빌라
# 1995  126.962085          고시원보다 싼 주차가능한 풀옵션 꿀매물 미쳤다
#
#                                       태그 물건층 전체층 비선호층여부
# 0              ['10년이내', '융자금적은', '역세권']   2   4      n
# 3              ['25년이내', '융자금적은', '역세권']   2   5      n
# 8              ['15년이내', '융자금없는', '역세권']   3   6      n
# 10             ['10년이내', '융자금적은', '역세권']   저   4      n
# 14            ['15년이내', '융자금적은', '세대분리']   저   4      n
# ...                                  ...  ..  ..    ...
# 1985           ['15년이내', '융자금적은', '역세권']   중   4      n
# 1986         ['15년이내', '융자금없는', '화장실한개']   저   3      n
# 1988           ['25년이상', '융자금적은', '역세권']   고   4      n
# 1989  ['25년이내', '융자금없는', '올수리', '화장실한개']   3   5      n
# 1995           ['25년이상', '융자금적은', '역세권']   3   4      n
#
# [826 rows x 17 columns]

# %% [markdown]
# - 태그 컬럼 분리

# %%
data_filtered[['tag1','tag2','tag3','tag4']] = data_filtered['태그'].str.replace("\'|\[|\]","").str.split(', ', expand=True)

# %%
data_filtered.head()
# Out:
#           물건번호  구분 층수(물건층/전체층)  월세   보증금 계약면적(m2)  전용면적(m2)   방향       확인일자  \
# 0   2339667467  원룸         2/4  55  1000       26     19.80  남서향  23.09.15.
# 3   2339568890  원룸         2/5  40  1000       20     16.00   서향  23.09.15.
# 8   2339681933  원룸         3/6  45   300       19     16.52   서향  23.09.15.
# 10  2339663561  원룸         저/4  35   500       26     19.80   서향  23.09.15.
# 14  2339661926  원룸         저/4  50  1000       26     19.80   동향  23.09.15.
#
#                                                   이미지  ...          경도  \
# 0   /20230915_104/land_naver_1694770741540Yco5Q_JP...  ...  126.939191
# 3   /20230915_271/land_naver_1694770562663jy052_JP...  ...  126.964993
# 8   /20230915_295/land_naver_1694786940564F4hWf_JP...  ...  126.927202
# 10  /20230915_24/land_naver_1694770860861HB3gt_JPE...  ...  126.952802
# 14  /20230915_72/land_naver_1694770860633nCaXR_JPE...  ...  126.949405
#
#                                    설명                          태그 물건층 전체층  \
# 0   봉천역도보권 신축급 채광좋고 방사이즈 좋은 깔끔한 분리형원룸   ['10년이내', '융자금적은', '역세권']   2   4
# 3                  낙성대역세권 수리되어 깔끔한 원룸   ['25년이내', '융자금적은', '역세권']   2   5
# 8       신림역  가성비 짱 분리형 원룸  위치도 너무 좋아요   ['15년이내', '융자금없는', '역세권']   3   6
# 10      서울대입구역도보권 신축급 가성비좋은 깨끗한 풀옵션원룸   ['10년이내', '융자금적은', '역세권']   저   4
# 14         서울대입구역도보권 방크기 좋은 깔끔한 분리형원룸  ['15년이내', '융자금적은', '세대분리']   저   4
#
#    비선호층여부   tag1   tag2  tag3  tag4
# 0       n  10년이내  융자금적은   역세권  None
# 3       n  25년이내  융자금적은   역세권  None
# 8       n  15년이내  융자금없는   역세권  None
# 10      n  10년이내  융자금적은   역세권  None
# 14      n  15년이내  융자금적은  세대분리  None
#
# [5 rows x 21 columns]

# %% [markdown]
# - 연식 컬럼 추가

# %%
data_filtered = data_filtered.query('tag1.str.contains("년")') #연식 정보가 있는 데이터만 필터링

# %%
data_filtered['연식'] = [int(i[0]) for i in data_filtered['tag1'].str.split('년')]
data_filtered
# Out:
#             물건번호  구분 층수(물건층/전체층)   월세   보증금 계약면적(m2)  전용면적(m2)   방향  \
# 0     2339667467  원룸         2/4   55  1000       26     19.80  남서향
# 3     2339568890  원룸         2/5   40  1000       20     16.00   서향
# 8     2339681933  원룸         3/6   45   300       19     16.52   서향
# 10    2339663561  원룸         저/4   35   500       26     19.80   서향
# 14    2339661926  원룸         저/4   50  1000       26     19.80   동향
# ...          ...  ..         ...  ...   ...      ...       ...  ...
# 1985  2339185628  빌라         중/4  100  2000       42     39.67  남동향
# 1986  2339175088  원룸         저/3   40   500       23     21.00  남동향
# 1988  2339199717  원룸         고/4   45   500       26     21.49  남동향
# 1989  2339203612  빌라         3/5   90  2000       52     45.60   서향
# 1995  2339187707  원룸         3/4   35   300       23     19.84  남동향
#
#            확인일자                                                이미지  ...  \
# 0     23.09.15.  /20230915_104/land_naver_1694770741540Yco5Q_JP...  ...
# 3     23.09.15.  /20230915_271/land_naver_1694770562663jy052_JP...  ...
# 8     23.09.15.  /20230915_295/land_naver_1694786940564F4hWf_JP...  ...
# 10    23.09.15.  /20230915_24/land_naver_1694770860861HB3gt_JPE...  ...
# 14    23.09.15.  /20230915_72/land_naver_1694770860633nCaXR_JPE...  ...
# ...         ...                                                ...  ...
# 1985  23.09.12.  /20230912_39/land_naver_1694487076985hxWAX_JPE...  ...
# 1986  23.09.12.  /20230912_15/land_naver_1694486124687snJyq_JPE...  ...
# 1988  23.09.12.  /20230914_12/land_naver_1694688064189IVgCU_JPE...  ...
# 1989  23.09.12.                                                NaN  ...
# 1995  23.09.12.  /20230912_116/land_naver_1694487156013f9nE6_JP...  ...
#
#                                      설명                                  태그  \
# 0     봉천역도보권 신축급 채광좋고 방사이즈 좋은 깔끔한 분리형원룸           ['10년이내', '융자금적은', '역세권']
# 3                    낙성대역세권 수리되어 깔끔한 원룸           ['25년이내', '융자금적은', '역세권']
# 8         신림역  가성비 짱 분리형 원룸  위치도 너무 좋아요           ['15년이내', '융자금없는', '역세권']
# 10        서울대입구역도보권 신축급 가성비좋은 깨끗한 풀옵션원룸           ['10년이내', '융자금적은', '역세권']
# 14           서울대입구역도보권 방크기 좋은 깔끔한 분리형원룸          ['15년이내', '융자금적은', '세대분리']
# ...                                 ...                                 ...
# 1985                                NaN           ['15년이내', '융자금적은', '역세권']
# 1986                역세권 깔끔하고 좋은 집 나왔습니다         ['15년이내', '융자금없는', '화장실한개']
# 1988             도림천뷰 인스타감성 초역세권 원룸꾸미기            ['25년이상', '융자금적은', '역세권']
# 1989      대로변 버스정류장바로 뒤.올수리.거실있는 방3개 빌라  ['25년이내', '융자금없는', '올수리', '화장실한개']
# 1995          고시원보다 싼 주차가능한 풀옵션 꿀매물 미쳤다           ['25년이상', '융자금적은', '역세권']
#
#      물건층 전체층 비선호층여부   tag1   tag2   tag3   tag4  연식
# 0      2   4      n  10년이내  융자금적은    역세권   None  10
# 3      2   5      n  25년이내  융자금적은    역세권   None  25
# 8      3   6      n  15년이내  융자금없는    역세권   None  15
# 10     저   4      n  10년이내  융자금적은    역세권   None  10
# 14     저   4      n  15년이내  융자금적은   세대분리   None  15
# ...   ..  ..    ...    ...    ...    ...    ...  ..
# 1985   중   4      n  15년이내  융자금적은    역세권   None  15
# 1986   저   3      n  15년이내  융자금없는  화장실한개   None  15
# 1988   고   4      n  25년이상  융자금적은    역세권   None  25
# 1989   3   5      n  25년이내  융자금없는    올수리  화장실한개  25
# 1995   3   4      n  25년이상  융자금적은    역세권   None  25
#
# [823 rows x 22 columns]

# %% [markdown]
# - 필요한 컬럼만 남기기

# %%
data_filtered.columns
# Out:
# Index(['물건번호', '구분', '층수(물건층/전체층)', '월세', '보증금', '계약면적(m2)', '전용면적(m2)', '방향',
#        '확인일자', '이미지', '위도', '경도', '설명', '태그', '물건층', '전체층', '비선호층여부', 'tag1',
#        'tag2', 'tag3', 'tag4', '연식'],
#       dtype='object')

# %%
data_filtered = data_filtered[['물건번호','월세','보증금','전용면적(m2)','방향','위도','경도','물건층','전체층','연식']]
data_filtered.head()
# Out:
#           물건번호  월세   보증금  전용면적(m2)   방향         위도          경도 물건층 전체층  연식
# 0   2339667467  55  1000     19.80  남서향  37.479689  126.939191   2   4  10
# 3   2339568890  40  1000     16.00   서향  37.478551  126.964993   2   5  25
# 8   2339681933  45   300     16.52   서향  37.486020  126.927202   3   6  15
# 10  2339663561  35   500     19.80   서향  37.484998  126.952802   저   4  10
# 14  2339661926  50  1000     19.80   동향  37.484270  126.949405   저   4  15

# %% [markdown]
# - 위도, 경도를 이용하여 역까지의 거리 재기

# %%
coordinate = pd.read_csv('/content/drive/MyDrive/강의자료_황수현_Python/Part3) 파이썬 데이터 분석 프로젝트/data/실습5: 교통 데이터를 활용한 지리 데이터 시각화/서울시 역사마스터 정보.csv', encoding='cp949')
coordinate = coordinate.query('호선 == "2호선"')
station_list = ['신대방', '신림', '봉천', '서울대입구(관악구청)', '낙성대', '사당']
coordinate.query('역사명 in @station_list')
# Out:
#      역사_ID          역사명   호선         위도          경도
# 727    231          신대방  2호선  37.487462  126.913149
# 728    230           신림  2호선  37.484201  126.929715
# 729    229           봉천  2호선  37.482362  126.941892
# 730    228  서울대입구(관악구청)  2호선  37.481247  126.952739
# 731    227          낙성대  2호선  37.476930  126.963693
# 732    226           사당  2호선  37.476538  126.981544

# %%
#위경도 거리 재는 라이브러리
# !pip install haversine
# Out:
# Requirement already satisfied: haversine in /usr/local/lib/python3.10/dist-packages (2.8.0)

# %%
from haversine import haversine

haversine((37.487462,126.913149), (37.484201,126.929715), unit = 'm')
# Out:
# 1505.9854014218406

# %%
def distance(station_name, lat, long):
    station_lat = coordinate.query(f'역사명 == "{station_name}"')['위도'].values[0]
    station_long = coordinate.query(f'역사명 == "{station_name}"')['경도'].values[0]

    distance = haversine((station_lat, station_long), (lat, long), unit = 'm')

    return distance

# %%
for s in station_list:
    data_filtered[s] = data_filtered.apply(lambda x: distance(s, x['위도'], x['경도']), axis=1)

# %%
data_filtered.head()
# Out:
#           물건번호  월세   보증금  전용면적(m2)   방향         위도          경도 물건층 전체층  연식  \
# 0   2339667467  55  1000     19.80  남서향  37.479689  126.939191   2   4  10
# 3   2339568890  40  1000     16.00   서향  37.478551  126.964993   2   5  25
# 8   2339681933  45   300     16.52   서향  37.486020  126.927202   3   6  15
# 10  2339663561  35   500     19.80   서향  37.484998  126.952802   저   4  10
# 14  2339661926  50  1000     19.80   동향  37.484270  126.949405   저   4  15
#
#             신대방           신림           봉천  서울대입구(관악구청)          낙성대  \
# 0   2455.029924   975.118310   380.980006  1207.963739  2183.777211
# 3   4680.643219  3175.659902  2082.015638  1122.088696   213.655993
# 8   1250.257936   300.127317  1358.504444  2314.951110  3374.841720
# 10  3509.424691  2039.012421  1006.291894   417.129788  1314.678540
# 14  3218.630513  1737.376094   696.044484   446.694269  1501.892777
#
#              사당
# 0   3753.736839
# 3   1477.571074
# 8   4909.637223
# 10  2705.027412
# 14  2963.409925

# %%
data_filtered['역까지최소거리'] = data_filtered.apply(lambda x: min([x['신대방'], x['신림'], x['봉천'], x['서울대입구(관악구청)'], x['낙성대'], x['사당']]), axis=1)
data_filtered.head()
# Out:
#           물건번호  월세   보증금  전용면적(m2)   방향         위도          경도 물건층 전체층  연식  \
# 0   2339667467  55  1000     19.80  남서향  37.479689  126.939191   2   4  10
# 3   2339568890  40  1000     16.00   서향  37.478551  126.964993   2   5  25
# 8   2339681933  45   300     16.52   서향  37.486020  126.927202   3   6  15
# 10  2339663561  35   500     19.80   서향  37.484998  126.952802   저   4  10
# 14  2339661926  50  1000     19.80   동향  37.484270  126.949405   저   4  15
#
#             신대방           신림           봉천  서울대입구(관악구청)          낙성대  \
# 0   2455.029924   975.118310   380.980006  1207.963739  2183.777211
# 3   4680.643219  3175.659902  2082.015638  1122.088696   213.655993
# 8   1250.257936   300.127317  1358.504444  2314.951110  3374.841720
# 10  3509.424691  2039.012421  1006.291894   417.129788  1314.678540
# 14  3218.630513  1737.376094   696.044484   446.694269  1501.892777
#
#              사당     역까지최소거리
# 0   3753.736839  380.980006
# 3   1477.571074  213.655993
# 8   4909.637223  300.127317
# 10  2705.027412  417.129788
# 14  2963.409925  446.694269

# %%
data_filtered.drop(station_list, axis=1, inplace=True)
data_filtered.head()
# Out:
#           물건번호  월세   보증금  전용면적(m2)   방향         위도          경도 물건층 전체층  연식  \
# 0   2339667467  55  1000     19.80  남서향  37.479689  126.939191   2   4  10
# 3   2339568890  40  1000     16.00   서향  37.478551  126.964993   2   5  25
# 8   2339681933  45   300     16.52   서향  37.486020  126.927202   3   6  15
# 10  2339663561  35   500     19.80   서향  37.484998  126.952802   저   4  10
# 14  2339661926  50  1000     19.80   동향  37.484270  126.949405   저   4  15
#
#        역까지최소거리
# 0   380.980006
# 3   213.655993
# 8   300.127317
# 10  417.129788
# 14  446.694269

# %% [markdown]
# ## **분석**

# %% [markdown]
# - 각 항목 분포 확인하기

# %%
for x in ['월세','보증금','전용면적(m2)','연식','역까지최소거리']:
    fig = px.box(data_frame = data_filtered, x=x, width=700, height=400)
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="dd63d73a-cfce-49c0-805b-badf34122bda" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd63d73a-cfce-49c0-805b-badf34122bda")) {                    Plotly.newPlot(                        "dd63d73a-cfce-49c0-805b-badf34122bda",                        [{"alignmentgroup":"True","hovertemplate":"\uc6d4\uc138=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[55,40,45,35,50,45,43,40,35,50,35,50,53,55,40,45,50,40,50,55,45,40,60,40,47,50,35,50,40,40,50,30,47,50,35,40,40,50,43,50,45,35,42,55,50,48,40,40,31,50,38,65,35,46,40,34,40,50,35,33,42,48,35,70,55,50,50,45,45,35,58,55,45,30,51,50,70,31,80,50,30,30,35,40,30,50,50,60,45,20,35,90,45,48,55,35,42,60,45,45,42,44,30,45,45,30,35,50,48,43,50,80,45,45,72,40,47,40,45,40,40,25,37,50,30,60,75,90,64,60,65,45,46,50,30,45,40,25,40,26,49,50,35,50,70,70,32,40,40,42,37,55,50,50,58,90,45,100,55,59,38,40,38,45,40,45,30,58,60,47,45,43,45,78,53,45,45,20,25,40,70,60,35,65,55,37,35,50,25,44,35,40,45,38,35,60,55,130,51,45,63,70,38,35,45,60,40,47,42,55,60,50,40,50,55
# %% [markdown]
# - 내가 원하는 조건은?
#     - 보증금 3000만원 이하 ✅
#     - 월세는 저렴할수록 좋음
#     - 지하, 반지하, 꼭대기층은 선호하지 않음 ✅
#     - 전용면적이 클수록 좋음
#     - 북향은 선호하지 않음 ✅
#     - 연식이 오래되지 않을수록 좋음
#     - 지하철 역에서 가까울수록 좋음

# %% [markdown]
# - 월세, 전용면적, 연식, 지하철역까지의 거리 점수 매기기

# %%
data_filtered
# Out:
#             물건번호   월세   보증금  전용면적(m2)   방향         위도          경도 물건층 전체층  연식  \
# 0     2339667467   55  1000     19.80  남서향  37.479689  126.939191   2   4  10
# 3     2339568890   40  1000     16.00   서향  37.478551  126.964993   2   5  25
# 8     2339681933   45   300     16.52   서향  37.486020  126.927202   3   6  15
# 10    2339663561   35   500     19.80   서향  37.484998  126.952802   저   4  10
# 14    2339661926   50  1000     19.80   동향  37.484270  126.949405   저   4  15
# ...          ...  ...   ...       ...  ...        ...         ...  ..  ..  ..
# 1985  2339185628  100  2000     39.67  남동향  37.473537  126.963900   중   4  15
# 1986  2339175088   40   500     21.00  남동향  37.474253  126.977329   저   3  15
# 1988  2339199717   45   500     21.49  남동향  37.475558  126.936207   고   4  25
# 1989  2339203612   90  2000     45.60   서향  37.472359  126.919879   3   5  25
# 1995  2339187707   35   300     19.84  남동향  37.478363  126.962085   3   4  25
#
#           역까지최소거리
# 0      380.980006
# 3      213.655993
# 8      300.127317
# 10     417.129788
# 14     446.694269
# ...           ...
# 1985   377.726864
# 1986   450.454340
# 1988   907.776276
# 1989  1577.096734
# 1995   213.364348
#
# [823 rows x 11 columns]

# %%
data_filtered['월세_등급'] = pd.qcut(data_filtered['월세'], 5, labels=[1,2,3,4,5])
data_filtered['전용면적_등급'] = pd.qcut(data_filtered['전용면적(m2)'], 5, labels=[5,4,3,2,1])
data_filtered['연식_등급'] = pd.qcut(data_filtered['연식'].rank(method='first'), 5, labels=[1,2,3,4,5])
data_filtered['역까지최소거리_등급'] = pd.qcut(data_filtered['역까지최소거리'], 5, labels=[1,2,3,4,5])

# %%
data_filtered
# Out:
#             물건번호   월세   보증금  전용면적(m2)   방향         위도          경도 물건층 전체층  연식  \
# 0     2339667467   55  1000     19.80  남서향  37.479689  126.939191   2   4  10
# 3     2339568890   40  1000     16.00   서향  37.478551  126.964993   2   5  25
# 8     2339681933   45   300     16.52   서향  37.486020  126.927202   3   6  15
# 10    2339663561   35   500     19.80   서향  37.484998  126.952802   저   4  10
# 14    2339661926   50  1000     19.80   동향  37.484270  126.949405   저   4  15
# ...          ...  ...   ...       ...  ...        ...         ...  ..  ..  ..
# 1985  2339185628  100  2000     39.67  남동향  37.473537  126.963900   중   4  15
# 1986  2339175088   40   500     21.00  남동향  37.474253  126.977329   저   3  15
# 1988  2339199717   45   500     21.49  남동향  37.475558  126.936207   고   4  25
# 1989  2339203612   90  2000     45.60   서향  37.472359  126.919879   3   5  25
# 1995  2339187707   35   300     19.84  남동향  37.478363  126.962085   3   4  25
#
#           역까지최소거리 월세_등급 전용면적_등급 연식_등급 역까지최소거리_등급
# 0      380.980006     4       4     1          2
# 3      213.655993     2       5     4          1
# 8      300.127317     2       5     2          2
# 10     417.129788     1       4     1          3
# 14     446.694269     3       4     2          3
# ...           ...   ...     ...   ...        ...
# 1985   377.726864     5       1     4          2
# 1986   450.454340     2       3     4          3
# 1988   907.776276     2       2     5          5
# 1989  1577.096734     5       1     5          5
# 1995   213.364348     1       3     5          1
#
# [823 rows x 15 columns]

# %%
data_filtered_final = data_filtered.query('월세_등급 <= 3 and 전용면적_등급 <= 1 and 연식_등급 <= 2 and 역까지최소거리_등급 <= 2')
data_filtered_final
# Out:
#             물건번호  월세   보증금  전용면적(m2)   방향         위도          경도 물건층 전체층  연식  \
# 753   2339901993  40   500     24.80  남동향  37.488173  126.917207   고   3  10
# 837   2339928778  50   500     23.23   동향  37.480379  126.944074   중  10  10
# 950   2339683475  50  2000     40.50  남서향  37.486231  126.928361   4  10  10
# 1107  2339671551  50  1000     23.20  남동향  37.482514  126.956022   고   3  10
# 1156  2339634395  48  1000     26.45  남동향  37.485928  126.928676   6  12   4
# 1317  2339637306  45  3000     24.75  남동향  37.486231  126.928361   4  10  10
# 1495  2339348847  45   500     26.46  남동향  37.485385  126.928474   고  10  10
# 1570  2339452836  40  3000     33.05  남동향  37.486530  126.927067   2   8  10
#
#          역까지최소거리 월세_등급 전용면적_등급 연식_등급 역까지최소거리_등급
# 753   366.667671     2       1     2          2
# 837   292.730018     3       1     2          2
# 950   255.392212     3       1     2          1
# 1107  322.128385     3       1     2          2
# 1156  212.794429     3       1     1          1
# 1317  255.392212     2       1     2          1
# 1495  171.240151     2       1     2          1
# 1570  348.793462     2       1     2          2

# %% [markdown]
# - 최종 매물 리스트 시각화

# %%
f = folium.Figure(width=700, height=500)
m = folium.Map(location=[37.486313, 126.935378], zoom_start=14).add_to(f)

for idx in data_filtered_final.index:
    lat = data_filtered_final.loc[idx, '위도']
    long = data_filtered_final.loc[idx, '경도']
    num = data_filtered_final.loc[idx, '물건번호']

    folium.Marker([lat, long]
                  , popup=f"<a href=https://m.land.naver.com/article/info/{num}>링크</a>"
                  ).add_to(m)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1cf080ef0b020bd61dc88460224d643a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1cf080ef0b020bd61dc88460224d643a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1cf080ef0b020bd61dc88460224d643a = L.map(
#                 &quot;map_1cf080ef0b020bd61dc88460224d643a&quot;,
#                 {
#                     center: [37.486313, 126.935378],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef7e5e5e224a1e265a9c09584adbab8a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1cf080ef0b020bd61dc88460224d643a);
#
#
#             var marker_836439b59e7049ce9ac66bf4754a6e20 = L.marker(
#                 [37.488173, 126.917207],
#                 {}
#             ).addTo(map_1cf080ef0b020bd61dc88460224d643a);
#
#
#         var popup_9de40265be405d2f03d1622f64611da1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ee235f430a5eb4bb55e3f0d605bd61ae = $(`&lt;div id=&quot;html_ee235f430a5eb4bb55e3f0d605bd61ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=https://m.land.naver.com/article/info/2339901993&gt;링크&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_9de40265be405d2f03d1622f64611da1.setContent(html_ee235f430a5eb4bb55e3f0d605bd61ae);
#
#
#
#         marker_836439b59e7049ce9ac66bf4754a6e20.bindPopup(popup_9de40265be405d2f03d1622f64611da1)
#         ;
#
#
#
#
#             var marker_6b36872c086b2ec1e35f9f74a76ff73d = L.marker(
#                 [37.480379, 126.944074],
#                 {}
#             ).addTo(map_1cf080ef0b020bd61dc88460224d643a);
#
#
#         var popup_fb07999ca48d07b123be019b84813026 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4b3c3ab04e9749dd3bf6ceecd4a51dc1 = $(`&lt;div id=&quot;html_4b3c3ab04e9749dd3bf6ceecd4a51dc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=https://m.land.naver.com/article/info/2339928778&gt;링크&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_fb07999ca48d07b123be019b84813026.setContent(html_4b3c3ab04e9749dd3bf6ceecd4a51dc1);
#
#
#
#         marker_6b36872c086b2ec1e35f9f74a76ff73d.bindPopup(popup_fb07999ca48d07b123be019b84813026)
#         ;
#
#
#
#
#             var marker_b70ff9450fe451f4b83c2cd89f551b39 = L.marker(
#                 [37.486231, 126.928361],
#                 {}
#             ).addTo(map_1cf080ef0b020bd61dc88460224d643a);
#
#
#         var popup_148679dfab3a6e16ab2861e1fce6eab8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eb62a5257fd4824c7e800960ff140901 = $(`&lt;div id=&quot;html_eb62a5257fd4824c7e800960ff140901&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=https://m.land.naver.com/article/info/2339683475&gt;링크&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_148679dfab3a6e16ab2861e1fce6eab8.setContent(html_eb62a5257fd4824c7e800960ff140901);
#
#
#
#         marker_b70ff9450fe451f4b83c2cd89f551b39.bindPopup(popup_148679dfab3a6e16ab2861e1fce6eab8)
#         ;
#
#
#
#
#             var marker_321a44f828ffdad5489efe68137ecb3e = L.marker(
#                 [37.482514, 126.956022],
#                 {}
#             ).addTo(map_1cf080ef0b020bd61dc88460224d643a);
#
#
#         var popup_71938f5d51f59de0f3f5a36539a99382 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eef09aa8bcd803b7b2850296bdedb69f = $(`&lt;div id=&quot;html_eef09aa8bcd803b7b2850296bdedb69f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=https://m.land.naver.com/article/info/2339671551&gt;링크&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_71938f5d51f59de0f3f5a36539a99382.setContent(html_eef09aa8bcd803b7b2850296bdedb69f);
#
#
#
#         marker_321a44f828ffdad5489efe68137ecb3e.bindPopup(popup_71938f5d51f59de0f3f5a36539a99382)
#         ;
#
#
#
#
#             var marker_238b70718fcc5d7cf3955617d83b57a3 = L.marker(
#                 [37.485928, 126.928676],
#                 {}
#             ).addTo(map_1cf080ef0b020bd61dc88460224d643a);
#
#
#         var popup_1b64d13171228bb2de4da71db60221c6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e079bdf45807715a4e5ed6ebae908fa5 = $(`&lt;div id=&quot;html_e079bdf45807715a4e5ed6ebae908fa5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=https://m.land.naver.com/article/info/2339634395&gt;링크&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_1b64d13171228bb2de4da71db60221c6.setContent(html_e079bdf45807715a4e5ed6ebae908fa5);
#
#
#
#         marker_238b70718fcc5d7cf3955617d83b57a3.bindPopup(popup_1b64d13171228bb2de4da71db60221c6)
#         ;
